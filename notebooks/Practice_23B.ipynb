# %% [markdown]
# ### <p style="text-align: right;"> &#9999; Krrish Kishore Kumar</p>

# %% [markdown]
# <img src='https://www.worldatlas.com/r/w960-q80/upload/d4/17/f3/mi-01.png'>

# %% [markdown]
# ---

# %% [markdown]
# ## 23B Representation in Lansing
#
# According to the [Michigan State Government](https://www.michigan.gov/som/government/branches-of-government/legislative-branch),
# The Michigan House of Representatives consists of 110 members who are elected by the qualified electors of districts having approximately 77,000 to 91,000 residents. Representatives are elected in even-numbered years to 2-year terms. Legislative districts are drawn on the basis of population figures obtained through the federal decennial census.
#
# The Michigan Senate consists of 38 members who are elected by the qualified electors of districts having approximately 212,400 to 263,500 residents. Senators are elected at the same time as the governor and serve 4-year terms concurrent with the governor's term of office. Terms for senators begin on January 1, following the November general election.
#
# **Download the 'Michigan Senate Map' from Schoology and load it into this file as a viewable image.** The image should appear to be about 5 x 7 inches on your screen. You will need to modify the image size to do this.

# %%
from IPython.display import Image

Image("Michigan_Senate_Map.png", width=500, height=700)

# %% [markdown]
# The map above demarcates the 38 Senatorial districts in the state of Michigan. Go to [the House of Representatives Maps](https://www.house.mi.gov/media/PDFs/housedistricts.pdf) to get a sense of the 110 different Representative districts in the state.
#
# Write down some of the things you notice about how the district lines are drawn.
#
# <font size=+2> &#9999;<font> The districts in rural northern Michigan are much larger geographically than those in densely populated areas like Detroit (shown in the Metro Wayne inset). The districts appear to follow some county boundaries but not consistently, with many districts crossing county lines. Metropolitan areas like Detroit have been divided into multiple smaller districts, likely to maintain similar population sizes across all districts despite the vast differences in population density throughout the state.

# %% [markdown]
# You can also look at your specific district by going to the Michigan State's [interactive map](https://www.mcgi.state.mi.us/districtlocator/). Go and explore how your district is drawn.
#
# What do you notice about the Senatorial versus Representative lines are drawn (aside from the size difference)? Why do you think that is?
#
# <font size=+2> &#9999;<font> Senate districts are bigger and cover more area, while Representative districts are smaller and more detailed. That’s because there are fewer Senators, so each one has to represent more people. Representative districts are drawn more tightly around neighborhoods to make sure different communities get a voice.

# %% [markdown]
# List at least three different ways data analytics or data science can impact the ways in which these lines are determined.
#
# <font size=+2> &#9999;<font>

# %% [markdown]
# Take some time and **document below what data you would want if you were in charge of drawing the district lines for Michigan.**
# Then **_find the datasets that have this information_** and put in links to the datasets below.
#
# <font size=+2> &#9999;<font>

# %% [markdown]
# ---

# %% [markdown]
# In the space below, type in your key learnings from this activity.
#
# <font size=+2> &#9999; </font>
